# %%
! wget https://download.data.world/s/mwqx4bs5uq2wqyrh2g7hq24tbflskz -O data_abc-news.csv
# Out:
# --2020-03-17 10:55:04--  https://download.data.world/s/mwqx4bs5uq2wqyrh2g7hq24tbflskz
# Resolving download.data.world (download.data.world)... 18.210.128.19, 107.23.216.235, 35.169.251.217
# Connecting to download.data.world (download.data.world)|18.210.128.19|:443... connected.
# HTTP request sent, awaiting response... 301 Moved Permanently
# Location: https://query.data.world/queries/martinchek/2012-2016-facebook-posts/621beb1d-15ef-4c2d-94d8-543bca5272ba/result_download?parameters&fileName=query_results&mimetype=text%2Fcsv&auth=eyJhbGciOiJIUzUxMiJ9..3xpioHZWL5j3hzzYQ4PcWAeaYEfeobZOJCfepMDgZFxEvNU9IGAZqKxjwCgA99rTiYuYxUFlCY23yB71bDidvQ [following]
# ...

# %%
! wget https://download.data.world/s/5f2na7qsavxopt3fnkelau5x7lfpni -O data_bbc-news.csv
# Out:
# --2020-03-17 10:55:10--  https://download.data.world/s/5f2na7qsavxopt3fnkelau5x7lfpni
# Resolving download.data.world (download.data.world)... 18.210.128.19, 107.23.216.235, 35.169.251.217
# Connecting to download.data.world (download.data.world)|18.210.128.19|:443... connected.
# HTTP request sent, awaiting response... 301 Moved Permanently
# Location: https://query.data.world/queries/martinchek/2012-2016-facebook-posts/184e83ce-0cd6-46c4-9dda-dcfcb4f8f1c5/result_download?parameters&fileName=query_results&mimetype=text%2Fcsv&auth=eyJhbGciOiJIUzUxMiJ9..OylrhpRHCMNhBIGvOwdMcFiUvgHURCGgUXzxEKE32DWCfIwKbT1AqQzhzHxtWHNTSuQPwazg1wCY_7t2Mr7eXg [following]
# ...

# %%
! wget https://download.data.world/s/qvfjtmkqvvdok6eadjmpmzkedkh27c -O data_cbs-news.csv
# Out:
# --2020-03-17 10:54:56--  https://download.data.world/s/qvfjtmkqvvdok6eadjmpmzkedkh27c
# Resolving download.data.world (download.data.world)... 18.210.128.19, 107.23.216.235, 35.169.251.217
# Connecting to download.data.world (download.data.world)|18.210.128.19|:443... connected.
# HTTP request sent, awaiting response... 301 Moved Permanently
# Location: https://query.data.world/queries/martinchek/2012-2016-facebook-posts/a96669ad-0ebd-4b89-a8fc-ea58aaba83b4/result_download?parameters&fileName=query_results&mimetype=text%2Fcsv&auth=eyJhbGciOiJIUzUxMiJ9..lgIMiYT1O7L8nJGLLy_Ag-vte0gp5QSWZNJ_HrmpvFCr1YkcL9cApbgNtK8_jbx0-VXOkC8gfCrSvF2BLvXczg [following]
# ...

# %%
! wget https://download.data.world/s/oedz6n5c5uykaqvqsqm6ojzdgkirnp -O data_cnn-news.csv
# Out:
# --2020-03-17 10:55:17--  https://download.data.world/s/oedz6n5c5uykaqvqsqm6ojzdgkirnp
# Resolving download.data.world (download.data.world)... 18.210.128.19, 107.23.216.235, 35.169.251.217
# Connecting to download.data.world (download.data.world)|18.210.128.19|:443... connected.
# HTTP request sent, awaiting response... 301 Moved Permanently
# Location: https://query.data.world/queries/martinchek/2012-2016-facebook-posts/77027604-4d87-4ebb-b5e2-0426d535464e/result_download?parameters&fileName=query_results&mimetype=text%2Fcsv&auth=eyJhbGciOiJIUzUxMiJ9..pKCkaiUWk-SyPWKJBhwVMYz0pa9ukshd8mLBqQYCrBVlmcJjL7qoBV7exe7LjrEWnInhi1FtAifHJrkJYrvmZw [following]
# ...

# %%
! wget https://download.data.world/s/m4agzm3hvz67a6u3iesjd2wlizupuy  -O data_fox-friends.csv
# Out:
# --2020-03-17 10:56:01--  https://download.data.world/s/m4agzm3hvz67a6u3iesjd2wlizupuy
# Resolving download.data.world (download.data.world)... 18.210.128.19, 35.169.251.217, 107.23.216.235
# Connecting to download.data.world (download.data.world)|18.210.128.19|:443... connected.
# HTTP request sent, awaiting response... 301 Moved Permanently
# Location: https://query.data.world/queries/martinchek/2012-2016-facebook-posts/5edf8ec4-1487-40f3-99f6-bf22c178c399/result_download?parameters&fileName=query_results&mimetype=text%2Fcsv&auth=eyJhbGciOiJIUzUxMiJ9..rtvCmLfvr4PTvX4O5yqp2iCKW5LXm16QdrX8vatGn4R-HGZqEH96nGn7aC7PS3fssrik1Ug5v1_KfUoKF8YzBw [following]
# ...

# %%
! wget https://download.data.world/s/cevulwmtyiy55v4sbwurd2erwjdwol -O data_fox-news.csv
# Out:
# --2020-03-17 10:56:49--  https://download.data.world/s/cevulwmtyiy55v4sbwurd2erwjdwol
# Resolving download.data.world (download.data.world)... 18.210.128.19, 35.169.251.217, 107.23.216.235
# Connecting to download.data.world (download.data.world)|18.210.128.19|:443... connected.
# HTTP request sent, awaiting response... 301 Moved Permanently
# Location: https://query.data.world/queries/martinchek/2012-2016-facebook-posts/5b18b5dd-2f2b-4cc0-9a24-7ba12f2c749e/result_download?parameters&fileName=query_results&mimetype=text%2Fcsv&auth=eyJhbGciOiJIUzUxMiJ9..XeKBYhrQ-gsrfHzXntWIFQTVaCgAoxjjdKPKUEHup_glMiu731JRXdmUpFd4ZQIfy3zhMzp-RZMzJYFdTwBozw [following]
# ...

# %%
! wget https://download.data.world/s/pphnt2ftnzdtrcyocgydwwso5p3zqi -O data_nbc-news.csv
# Out:
# --2020-03-17 10:57:42--  https://download.data.world/s/pphnt2ftnzdtrcyocgydwwso5p3zqi
# Resolving download.data.world (download.data.world)... 107.23.216.235, 35.169.251.217, 18.210.128.19
# Connecting to download.data.world (download.data.world)|107.23.216.235|:443... connected.
# HTTP request sent, awaiting response... 301 Moved Permanently
# Location: https://query.data.world/queries/martinchek/2012-2016-facebook-posts/fba787e2-d6d9-474c-8147-fd9eee743757/result_download?parameters&fileName=query_results&mimetype=text%2Fcsv&auth=eyJhbGciOiJIUzUxMiJ9..bkJVsgDJDqZBYqiKi9WtlfhuL-9X2GzL5b4wZKbo8rBDJFRqVwJYzxGWHa6ERAgPxdEDkK1P2-6rsyoD0I-6uA [following]
# ...

# %%
! wget https://download.data.world/s/ivfbt6s6b5ufo7oqxp2i2ac5aqrhlk -O data_npr.csv
# Out:
# --2020-03-17 11:03:39--  https://download.data.world/s/ivfbt6s6b5ufo7oqxp2i2ac5aqrhlk
# Resolving download.data.world (download.data.world)... 107.23.216.235, 18.210.128.19, 35.169.251.217
# Connecting to download.data.world (download.data.world)|107.23.216.235|:443... connected.
# HTTP request sent, awaiting response... 301 Moved Permanently
# Location: https://query.data.world/queries/martinchek/2012-2016-facebook-posts/f6a6c100-3960-4d18-914a-a0a638f34280/result_download?parameters&fileName=query_results&mimetype=text%2Fcsv&auth=eyJhbGciOiJIUzUxMiJ9..2nHbw4Y5C9ouwOC-XJeyAvvgJReuHufK3APGRmev-IYFEW0BlbxR4z090ap0onK_z5BGFd7IulVdEaZbQH038g [following]
# ...

# %%
! wget https://query.data.world/s/wyuaj4isthgped5nuqjgexw3h44kqi -O data_huffington-posting.csv
# Out:
# --2020-03-17 11:10:36--  https://query.data.world/s/wyuaj4isthgped5nuqjgexw3h44kqi
# Resolving query.data.world (query.data.world)... 35.169.251.217, 18.210.128.19, 107.23.216.235
# Connecting to query.data.world (query.data.world)|35.169.251.217|:443... connected.
# HTTP request sent, awaiting response... 301 Moved Permanently
# Location: https://download.data.world/file_download/martinchek/2012-2016-facebook-posts/the-huffington-post-18468761129.csv%2Fthe-huffington-post-18468761129.csv?auth=eyJhbGciOiJIUzUxMiJ9..jgOq-GTkydAKAe5zHWdeH6c77wibIGrXI7jBTlN7wqYdbhlFs7unYXtn1TvUMhLKlfmaX4Ie1xBVVOOKcyDSkQ [following]
# ...

# %%
! wget https://download.data.world/s/ncv6frqxau2yhtwxlkwnqgtnn6ig4b -O data_la-times.csv
# Out:
# --2020-03-17 11:05:29--  https://download.data.world/s/ncv6frqxau2yhtwxlkwnqgtnn6ig4b
# Resolving download.data.world (download.data.world)... 35.169.251.217, 18.210.128.19, 107.23.216.235
# Connecting to download.data.world (download.data.world)|35.169.251.217|:443... connected.
# HTTP request sent, awaiting response... 301 Moved Permanently
# Location: https://query.data.world/queries/martinchek/2012-2016-facebook-posts/e7276469-9e38-4621-a5e2-58d97f02151e/result_download?parameters&fileName=query_results&mimetype=text%2Fcsv&auth=eyJhbGciOiJIUzUxMiJ9..FO9LpR9b9tk_aUvFBwAn5M9hL_w08IkXz9mLBi_7-tquSdBrBZbFLtM_R9n6UAoz5CBIu-WWmMiglIUTIchm4A [following]
# ...

# %%
! wget https://query.data.world/s/gyonadyrwvavoguudmfqbgshgaykzt  -O new-york.csv
# Out:
# --2020-03-16 05:01:18--  https://query.data.world/s/gyonadyrwvavoguudmfqbgshgaykzt
# Resolving query.data.world (query.data.world)... 35.169.251.217, 18.210.128.19, 107.23.216.235
# Connecting to query.data.world (query.data.world)|35.169.251.217|:443... connected.
# HTTP request sent, awaiting response... 301 Moved Permanently
# Location: https://download.data.world/file_download/martinchek/2012-2016-facebook-posts/the-new-york-times-5281959998.csv%2Fthe-new-york-times-5281959998.csv?auth=eyJhbGciOiJIUzUxMiJ9..MtQeVbxqT0YAXpuRvLe17e25OTo11SMyjmd7kR9cxjbxwgads7nAtHckQy80QEQgZ6ZnC9xmf1Y4Qk2tiv6sYQ [following]
# ...

# %%
! wget https://query.data.world/s/4nasrvwunrvju66zb2eumwq7fe54y6 -O wallstreet.csv
# Out:
# --2020-03-16 05:00:38--  https://query.data.world/s/4nasrvwunrvju66zb2eumwq7fe54y6
# Resolving query.data.world (query.data.world)... 18.210.128.19, 107.23.216.235, 35.169.251.217
# Connecting to query.data.world (query.data.world)|18.210.128.19|:443... connected.
# HTTP request sent, awaiting response... 301 Moved Permanently
# Location: https://download.data.world/file_download/martinchek/2012-2016-facebook-posts/the-wall-street-journal-8304333127.csv%2Fthe-wall-street-journal-8304333127.csv?auth=eyJhbGciOiJIUzUxMiJ9..VsLKJcvDtNkdijThfkLjARmv5C_LJ4fjCkaf6JJb7cCAMlPyexlhQ954lpZXILj84Nx4u4fO1sVyDS44M2uaaw [following]
# ...

# %%
! wget https://query.data.world/s/gxv4apyy4vbggwghaa6ii36oozjnvr -O washington.csv
# Out:
# --2020-03-16 05:02:56--  https://query.data.world/s/gxv4apyy4vbggwghaa6ii36oozjnvr
# Resolving query.data.world (query.data.world)... 35.169.251.217, 107.23.216.235, 18.210.128.19
# Connecting to query.data.world (query.data.world)|35.169.251.217|:443... connected.
# HTTP request sent, awaiting response... 301 Moved Permanently
# Location: https://download.data.world/file_download/martinchek/2012-2016-facebook-posts/the-washington-post-6250307292.csv%2Fthe-washington-post-6250307292.csv?auth=eyJhbGciOiJIUzUxMiJ9..GC28wfvSzAQJeP2QnScGlfzFeCT1U5R807Z2I0vNf4F0vdJlJ-OeYTzl1TC5ppq34FMY4YXbRMeRdp7zb0whaA [following]
# ...

# %%
! wget https://query.data.world/s/3g6a37s5havng4uab6ls6c5vj2ahjy -O time.csv
# Out:
# --2020-03-16 05:03:30--  https://query.data.world/s/3g6a37s5havng4uab6ls6c5vj2ahjy
# Resolving query.data.world (query.data.world)... 35.169.251.217, 107.23.216.235, 18.210.128.19
# Connecting to query.data.world (query.data.world)|35.169.251.217|:443... connected.
# HTTP request sent, awaiting response... 301 Moved Permanently
# Location: https://download.data.world/file_download/martinchek/2012-2016-facebook-posts/time-10606591490.csv%2Ftime-10606591490.csv?auth=eyJhbGciOiJIUzUxMiJ9..LrCHcGwqQD8hzX8Uo5k09_MWJOi8ZW0fYtzUP-sGAtdz0coN_--mIScnYvbNab8uSpCCD91Aw0UX2k2PfBGjPQ [following]
# ...

# %%
! wget https://query.data.world/s/affhs7vrexwfg675m426aaiyjbpnjx -O usa-today.csv
# Out:
# --2020-03-16 05:04:00--  https://query.data.world/s/affhs7vrexwfg675m426aaiyjbpnjx
# Resolving query.data.world (query.data.world)... 18.210.128.19, 35.169.251.217, 107.23.216.235
# Connecting to query.data.world (query.data.world)|18.210.128.19|:443... connected.
# HTTP request sent, awaiting response... 301 Moved Permanently
# Location: https://download.data.world/file_download/martinchek/2012-2016-facebook-posts/usa-today-13652355666.csv%2Fusa-today-13652355666.csv?auth=eyJhbGciOiJIUzUxMiJ9..R84ZQ1NkNdk85uOMlb2GoTyu4OSpTIH9L25z5BC3nwOQd7N6jAQJ083qjRJzNcUfLVF-JVf951dj9S2kXSXXXQ [following]
# ...

# %%
! hdfs dfs -put data_abc-news.csv

# %%
! hdfs dfs -put data_bbc-news.csv

# %%
! hdfs dfs -put data_cbs-news.csv

# %%
! hdfs dfs -put data_cnn-news.csv

# %%
! hdfs dfs -put data_fox-friends.csv

# %%
! hdfs dfs -put data_fox-news.csv

# %%
! hdfs dfs -put data_nbc-news.csv

# %%
! hdfs dfs -put data_npr.csv

# %%
! hdfs dfs -put data_huffington-posting.csv

# %%
! hdfs dfs -put data_la-times.csv

# %%
! hdfs dfs -ls
# Out:
# Found 11 items
# drwxr-xr-x   - root hadoop          0 2020-03-17 08:40 .sparkStaging
# -rw-r--r--   2 root hadoop    3310194 2020-03-17 11:06 data_abc-news.csv
# -rw-r--r--   2 root hadoop    2837402 2020-03-17 11:06 data_bbc-news.csv
# -rw-r--r--   2 root hadoop    3711572 2020-03-17 11:06 data_cbs-news.csv
# -rw-r--r--   2 root hadoop    3125897 2020-03-17 11:06 data_cnn-news.csv
# -rw-r--r--   2 root hadoop    2745384 2020-03-17 11:06 data_fox-friends.csv
# -rw-r--r--   2 root hadoop    3327920 2020-03-17 11:06 data_fox-news.csv
# -rw-r--r--   2 root hadoop   23347042 2020-03-17 11:06 data_huffington-post.csv
# -rw-r--r--   2 root hadoop    4078695 2020-03-17 11:06 data_la-times.csv
# -rw-r--r--   2 root hadoop    3491617 2020-03-17 11:06 data_nbc-news.csv
# -rw-r--r--   2 root hadoop    3446162 2020-03-17 11:06 data_npr.csv

# %%
pip install pandas
# Out:
# ...
#      |████████████████████████████████| 10.1MB 3.2MB/s eta 0:00:01
# ...
#      |████████████████████████████████| 512kB 37.0MB/s eta 0:00:01
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import os, glob
import pandas as pd

# %%
! hdfs dfs -p
# Out:
# -p: Unknown command
# Usage: hadoop fs [generic options]
# 	[-appendToFile <localsrc> ... <dst>]
# 	[-cat [-ignoreCrc] <src> ...]
# 	[-checksum <src> ...]
# 	[-chgrp [-R] GROUP PATH...]
# 	[-chmod [-R] <MODE[,MODE]... | OCTALMODE> PATH...]
# 	[-chown [-R] [OWNER][:[GROUP]] PATH...]
# 	[-copyFromLocal [-f] [-p] [-l] [-d] <localsrc> ... <dst>]
# 	[-copyToLocal [-f] [-p] [-ignoreCrc] [-crc] <src> ... <localdst>]
# 	[-count [-q] [-h] [-v] [-t [<storage type>]] [-u] [-x] <path> ...]
# 	[-cp [-f] [-p | -p[topax]] [-d] <src> ... <dst>]
# 	[-createSnapshot <snapshotDir> [<snapshotName>]]
# 	[-deleteSnapshot <snapshotDir> <snapshotName>]
# 	[-df [-h] [<path> ...]]
# 	[-du [-s] [-h] [-x] <path> ...]
# 	[-expunge]
# 	[-find <path> ... <expression> ...]
# 	[-get [-f] [-p] [-ignoreCrc] [-crc] <src> ... <localdst>]
# 	[-getfacl [-R] <path>]
# 	[-getfattr [-R] {-n name | -d} [-e en] <path>]
# 	[-getmerge [-nl] [-skip-empty-file] <src> <localdst>]
# 	[-help [cmd ...]]
# ...

# %%
path = "/hdfs/dfs"

# %%
# !hdfs dfs -ls
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# <ipython-input-73-a4928e0d1be2> in <module>
# ----> 1 get_ipython().system('hdfs dfs -ls')
#
# /opt/conda/lib/python3.7/site-packages/IPython/core/interactiveshell.py in system_piped(self, cmd)
#    2454         # a non-None value would trigger :func:`sys.displayhook` calls.
#    2455         # Instead, we store the exit_code in user_ns.
# -> 2456         self.user_ns['_exit_code'] = system(self.var_expand(cmd, depth=1))
#    2457
#    2458     def system_raw(self, cmd):
#
# /opt/conda/lib/python3.7/site-packages/IPython/utils/_process_posix.py in system(self, cmd)
#     154                 child = pexpect.spawnb(self.sh, args=['-c', cmd]) # Pexpect-U
#     155             else:
# --> 156                 child = pexpect.spawn(self.sh, args=['-c', cmd])  # Vanilla Pexpect
#     157             flush = sys.stdout.flush
# ...

# %%
all_files = glob.glob(os.path.join(path, "data_*.csv"))

# %%
df_merged = (pd.read_csv(f, sep=',') for f in all_files)

# %%
df_merged   = pd.concat(df_from_each_file, ignore_index=True)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-62-72f9f48b90ca> in <module>
# ----> 1 df_merged   = pd.concat(df_from_each_file, ignore_index=True)
#
# NameError: name 'df_from_each_file' is not defined

# %%
! hdfs dfs  -mkdir -p  /user/new/input

# %%
! hadoop fs -put data_abc-news.csv /user/new/input

# %%
! hadoop fs -put data_bbc-news.csv /user/new/input

# %%
! hadoop fs -put data_cbs-news.csv /user/new/input

# %%
! hadoop fs -put data_cnn-news.csv /user/new/input

# %%
! hadoop fs -put data_fox-news.csv /user/new/input

# %%
! hadoop fs -put data_nbc-news.csv /user/new/input

# %%
! hadoop fs -put data_fox-friends.csv /user/new/input

# %%
! hadoop fs -put data_npr.csv /user/new/input

# %%
! hadoop fs -put data_huffington-posting.csv /user/new/input

# %%
! hadoop fs -put data_la-times.csv /user/new/input

# %%
abc = sc.textFile("hdfs:///user/new/input/data_abc-news.csv")

# %%
bbc = sc.textFile("hdfs:///user/new/input/data_bbc-news.csv")

# %%
cbs = sc.textFile("hdfs:///user/new/input/data_cbs-news.csv")

# %%
fox = sc.textFile("hdfs:///user/new/input/data_fox-news.csv")

# %%
cnn = sc.textFile("hdfs:///user/new/input/data_cnn-news.csv")

# %%
friends = sc.textFile("hdfs:///user/new/input/data_fox-friends.csv")

# %%
nbc = sc.textFile("hdfs:///user/new/input/data_nbc-news.csv")

# %%
huffing = sc.textFile("hdfs:///user/new/input/data_huffington-posting.csv")

# %%
npr = sc.textFile("hdfs:///user/new/input/data_npr.csv")

# %%
la = sc.textFile("hdfs:///user/new/input/data_la-times.csv")

# %%
abc.take(2)
# Out:
# ['id,page_id,name,message,description,caption,post_type,status_type,likes_count,comments_count,shares_count,love_count,wow_count,haha_count,sad_count,thankful_count,angry_count,link,picture,posted_at',
# ...

# %%
bbc.take(2)
# Out:
# ['id,page_id,name,message,description,caption,post_type,status_type,likes_count,comments_count,shares_count,love_count,wow_count,haha_count,sad_count,thankful_count,angry_count,link,picture,posted_at',
#  '"\ufeff""228735667216_10151160265682217""",228735667216,BBC News Photos,Your best photographs of 2012. GALLERY: http://bbc.in/UvZxmS,NULL,NULL,photo,added_photos,242,6,45,0,0,0,0,0,0,https://www.facebook.com/bbcnews/photos/a.10150883570262217.403741.228735667216/10151160265662217/?type=3,https://scontent.xx.fbcdn.net/v/t1.0-0/s130x130/301847_10151160265662217_671124224_n.jpg?oh=7317dfec07b4f894a063e826b798fcce&oe=58A9EF0E,2012-12-30T09:16:36']

# %%
friends.take(2)
# Out:
# ['id,page_id,name,message,description,caption,post_type,status_type,likes_count,comments_count,shares_count,love_count,wow_count,haha_count,sad_count,thankful_count,angry_count,link,picture,posted_at',
#  '"\ufeff""111938618893743_307387555980215""",111938618893743,Mitt Romney on \'Fox & Friends\' - Fox News Video - Fox News,"If you missed Gov. Romney\'s interview this morning, check it out here!http://video.foxnews.com/v/1412957663001/",2012 candidate reacts to State of the Union address,video.foxnews.com,video,shared_story,35,39,5,0,0,0,0,0,0,http://video.foxnews.com/v/1412957663001/mitt-romney-on-fox--friends/,https://external.xx.fbcdn.net/safe_image.php?d=AQCltcyzLvgzvxL3&w=130&h=130&url=http%3A%2F%2Fvideo.foxnews.com%2Fthumbnails%2F012512%2F121%2F68%2F012512_ff_romney_640.jpg&cfs=1,2012-01-25T19:20:55']

# %%
fox.take(2)
# Out:
# ['id,page_id,name,message,description,caption,post_type,status_type,likes_count,comments_count,shares_count,love_count,wow_count,haha_count,sad_count,thankful_count,angry_count,link,picture,posted_at',
#  '"\ufeff""15704546335_10150581339721336""",15704546335,10 Years at Number 1,NULL,Fox News becomes the number 1 cable news network for 10 straight years.,10 Years at Number 1,photo,NULL,47,26,0,0,0,0,0,0,0,https://www.facebook.com/FoxNews/photos/p.10150581339681336/10150581339681336/?type=3,https://scontent.xx.fbcdn.net/v/t1.0-0/s130x130/432174_10150581339681336_313756437_n.jpg?oh=5e1ea26103304f1a4b1bc4661c0e4437&oe=588E3749,2012-01-01T08:00:00']

# %%
cnn.take(2)
# Out:
# ['id,page_id,name,message,description,caption,post_type,status_type,likes_count,comments_count,shares_count,love_count,wow_count,haha_count,sad_count,thankful_count,angry_count,link,picture,posted_at',
#  '"\ufeff""5550296508_10150712177946509""",5550296508,NULL,Breaking News: French prosecutors: Former IMF chief Dominique Strauss-Kahn charged with \'aggravated pimping.\' - http://bit.ly/qx5qjZ,NULL,NULL,status,mobile_status_update,348,143,201,0,0,0,0,0,0,NULL,NULL,2012-03-26T21:27:01']

# %%
la.take(2)
# Out:
# ['id,page_id,name,message,description,caption,post_type,status_type,likes_count,comments_count,shares_count,love_count,wow_count,haha_count,sad_count,thankful_count,angry_count,link,picture,posted_at',
#  '"\ufeff""5863113009_10150690970288010""",5863113009,Egypt\'s military is trying to protect its business empire,"As a power transition looms in Egypt, the military bargains with the Muslim Brotherhood to protect its widespread but murky business dealings."," The Egyptian military stamps itself as protector of the nation, but behind this carefully tended mythology the army controls a multibillion-dollar...",www.latimes.com,link,published_story,54,9,0,0,0,0,0,0,0,"http://www.latimes.com/news/nationworld/world/la-fg-egypt-military-20120325,0,6049014.story",https://external.xx.fbcdn.net/safe_image.php?d=AQBAac8F3LD7lkRS&w=130&h=130&url=http%3A%2F%2Fwww.trbimg.com%2Fimg-4f6e7417%2Fturbine%2Fla-mideast-egypt-coptic-pope-jpeg-0544d.jpg-20120324%2F187%2F16x9&cfs=1,2012-03-25T04:24:15']

# %%
nbc.take(2)
# Out:
# ['id,page_id,name,message,description,caption,post_type,status_type,likes_count,comments_count,shares_count,love_count,wow_count,haha_count,sad_count,thankful_count,angry_count,link,picture,posted_at',
#  '"\ufeff""155869377766434_244391768964775""",155869377766434,Revelers welcome 2012 in Times Square,Watch live as revelers ring in the new year in New York\'s Times Square.,LIVE VIDEO — Millions celebrate the the new year in New York\'s Times Square.,msnbc.msn.com,video,shared_story,51,10,7,0,0,0,0,0,0,http://www.msnbc.msn.com/id/45836814/displaymode/1283/for/facebookvideo,https://external.xx.fbcdn.net/safe_image.php?d=AQAvJD5G0vnMKgOE&w=130&h=130&url=http%3A%2F%2Fmsnbcmedia.msn.com%2Fj%2Fmsnbc%2Fcomponents%2Fvideo%2Flive%2Ftsquare.sub.02.standard.jpg&cfs=1,2012-01-01T02:07:14']

# %%
npr.collect()
# Out:
# ['id,page_id,name,message,description,caption,post_type,status_type,likes_count,comments_count,shares_count,love_count,wow_count,haha_count,sad_count,thankful_count,angry_count,link,picture,posted_at',
#  '"\ufeff""10643211755_255251391226420""",10643211755,From KPLU: Why most people get divorced in March,NULL,Divorce is a nasty business and this time of the year business is booming. KPLU looks at the reasons divorce filings peak in March every year.,kplu.org,link,shared_story,538,244,525,0,0,0,0,0,0,http://www.kplu.org/post/why-most-people-get-divorced-march,https://external.xx.fbcdn.net/safe_image.php?d=AQDfZ4ruY3ZHcwTr&w=130&h=130&url=http%3A%2F%2Fmediad.publicbroadcasting.net%2Fp%2Fkplu%2Ffiles%2Fdivorce_sign.jpg&cfs=1,2012-03-07T12:50:24',
# ...

# %%
bbc.take(2)
# Out:
# ['id,page_id,name,message,description,caption,post_type,status_type,likes_count,comments_count,shares_count,love_count,wow_count,haha_count,sad_count,thankful_count,angry_count,link,picture,posted_at',
#  '"\ufeff""228735667216_10151160265682217""",228735667216,BBC News Photos,Your best photographs of 2012. GALLERY: http://bbc.in/UvZxmS,NULL,NULL,photo,added_photos,242,6,45,0,0,0,0,0,0,https://www.facebook.com/bbcnews/photos/a.10150883570262217.403741.228735667216/10151160265662217/?type=3,https://scontent.xx.fbcdn.net/v/t1.0-0/s130x130/301847_10151160265662217_671124224_n.jpg?oh=7317dfec07b4f894a063e826b798fcce&oe=58A9EF0E,2012-12-30T09:16:36']

# %%
cbs.take(2)
# Out:
# ['id,page_id,name,message,description,caption,post_type,status_type,likes_count,comments_count,shares_count,love_count,wow_count,haha_count,sad_count,thankful_count,angry_count,link,picture,posted_at',
# ...

# %%
huffing.take(2)
# Out:
# ["\x1f�\x08\x00\x00\x00\x00\x00\x00\x00�kO[��.X��s�\x0fGz_�{�>��%&�7.�^-qK ��\x02\x12VV�\x15�\x068\x18�e\x1b\x08���'�t�xƨQ5=mτئO+J\x02��Y�.ϸ?�\x7f�?\x7f7m�4\x7f7��\uf769�+�2_�\u05fa��[�\x1a~s?",
#  '�\x1f|\x0e�5鵆��oݙ���g���\x1a�������\x03��\x17����&�q����{�S�����']

# %%
header_text = abc.first()

# %%
header_text
# Out:
# 'id,page_id,name,message,description,caption,post_type,status_type,likes_count,comments_count,shares_count,love_count,wow_count,haha_count,sad_count,thankful_count,angry_count,link,picture,posted_at'

# %%
abc1 = abc.filter(lambda row:row!=header_text)

# %%
bbc1 = bbc.filter(lambda row:row!=header_text)

# %%
cnn1 = cnn.filter(lambda row:row!=header_text)

# %%
cbs1 = cbs.filter(lambda row:row!=header_text)

# %%
friends1 = friends.filter(lambda row:row!=header_text)

# %%
fox1 = fox.filter(lambda row:row!=header_text)

# %%
nbc1 = nbc.filter(lambda row:row!=header_text)

# %%
npr1 = npr.filter(lambda row:row!=header_text)

# %%
huffing1 = huffing.filter(lambda row:row!=header_text)

# %%
la1 = la.filter(lambda row:row!=header_text)

# %%
 cnn2 = abc1.union(bbc1)

# %%
cnn2
# Out:
# UnionRDD[34] at union at NativeMethodAccessorImpl.java:0

# %%
cnn3 =  cnn2.union(cnn1)

# %%
cnn4 = cnn3.union(cbs1)

# %%
cnn5 = cnn4.union(friends1)

# %%
cnn6 = cnn5.union(fox1)

# %%
cnn7 = cnn6.union(nbc1)

# %%
cnn8 = cnn7.union(npr1)

# %%
cnn9 = cnn8.union(huffing1)

# %%
cnn10 = cnn8.union(la1)

# %%
fieldname = header_text.split(",")

# %%
def make_row(row):
    fieldvalue = row.split(",")
    d =dict(zip(fieldname,fieldvalue))
    return d

# %%
airline = cnn10.map(make_row)

# %%
sepu = airline.toDF()
# Out:
# /usr/lib/spark/python/pyspark/sql/session.py:360: UserWarning: Using RDD of dict to inferSchema is deprecated. Use pyspark.sql.Row instead
#   warnings.warn("Using RDD of dict to inferSchema is deprecated. "

# %%
sepu
# Out:
# DataFrame[angry_count: string, caption: string, comments_count: string, description: string, haha_count: string, id: string, likes_count: string, link: string, love_count: string, message: string, name: string, page_id: string, picture: string, post_type: string, posted_at: string, sad_count: string, shares_count: string, status_type: string, thankful_count: string, wow_count: string]

# %%
tyo = sepu

# %%
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-70-09588017317f> in <module>
# ----> 1 tyo.drop(['angry_count','comments_count','haha_count','id','like_count','sad_count','wow_count','thankful_count','shares_count'])
#
# /usr/lib/spark/python/pyspark/sql/dataframe.py in drop(self, *cols)
#    1894                 jdf = self._jdf.drop(col._jc)
#    1895             else:
# -> 1896                 raise TypeError("col should be a string or a Column")
#    1897         else:
#    1898             for col in cols:
#
# TypeError: col should be a string or a Column

# %%
from functools import reduce
from pyspark.sql import DataFrame

abcd =reduce(DataFrame.drop, ['angry_count','comments_count','haha_count','id','likes_count','sad_count','wow_count','thankful_count','shares_count','love_count','page_id','picture'], tyo)

# %%
abcd
# Out:
# DataFrame[caption: string, description: string, link: string, message: string, name: string, post_type: string, posted_at: string, status_type: string]

# %%
abcd.take(2)
# Out:
# [Row(caption='abcnews.go.com', description='PAUL J. RICHARDS/AFP/Getty Images Chief Justice John Roberts issued a ringing endorsement Saturday night of his colleagues’ ability to determine when they should step down from a case because of a conflict of interest. “I have complete confidence in the capability of my colleagues to determine when ...', link='http://abcnews.go.com/blogs/headlines/2011/12/chief-justice-roberts-responds-to-judicial-ethics-critics/', message='Roberts took the unusual step of devoting the majority of  his annual  report to the issue of judicial ethics.', name='Chief Justice Roberts Responds to Judicial Ethics Critics', post_type='link', posted_at='2012-01-01T00:30:26', status_type='shared_story'),
# ...

# %%
quering = abcd.registerTempTable("helloing")

# %%
resultcheck = sqlContext.sql("select name,count(name) as vals from helloing group by name order by vals desc limit 30 ").show()
# Out:
# +--------------------+----+
# |                name|vals|
# +--------------------+----+
# |     Timeline Photos|8685|
# |                NULL|5543|
# |              cnn.it| 131|
# |Photos from BBC N...| 129|
# |            L.A. Now| 122|
# |Fox & Friends - F...|  81|
# |             New Day|  79|
# |         BBC Stories|  71|
# |  Today's front page|  65|
# |        Page 1 Today|  57|
# |          BBC Shorts|  57|
# |           BBC Sport|  52|
# |NBC News's cover ...|  45|
# |        AT This HOUR|  43|
# |    CBS This Morning|  40|
# |          60 Minutes|  38|
# |            Fox News|  37|
# |The Voyage of the...|  34|
# |              "Obama|  32|
# |Photos from CNN's...|  30|
# +--------------------+----+
# only showing top 20 rows

# %%
def listToString(s):  
    
    # initialize an empty string 
    str1 = " "  
    
    # traverse in the string   
    for ele in s:  
        str1 += ele   
    
    # return string   
    return str1

# %%
c = sepu.collect()

# %%
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-103-f603af8aa0f1> in <module>
# ----> 1 d = sepu.split(",")
#
# /usr/lib/spark/python/pyspark/sql/dataframe.py in __getattr__(self, name)
#    1180         if name not in self.columns:
#    1181             raise AttributeError(
# -> 1182                 "'%s' object has no attribute '%s'" % (self.__class__.__name__, name))
#    1183         jc = self._jdf.apply(name)
#    1184         return Column(jc)
#
# AttributeError: 'DataFrame' object has no attribute 'split'

# %%
abc2 = abc1.collect()

# %%
abc2
# Out:
# ['"\ufeff""86680728811_272953252761568""",86680728811,Chief Justice Roberts Responds to Judicial Ethics Critics,Roberts took the unusual step of devoting the majority of  his annual  report to the issue of judicial ethics.,PAUL J. RICHARDS/AFP/Getty Images Chief Justice John Roberts issued a ringing endorsement Saturday night of his colleagues’ ability to determine when they should step down from a case because of a conflict of interest. “I have complete confidence in the capability of my colleagues to determine when ...,abcnews.go.com,link,shared_story,61,27,12,0,0,0,0,0,0,http://abcnews.go.com/blogs/headlines/2011/12/chief-justice-roberts-responds-to-judicial-ethics-critics/,https://external.xx.fbcdn.net/safe_image.php?d=AQAPXteeHLT2K7Rb&w=130&h=130&url=http%3A%2F%2Fabcnews.go.com%2Fimages%2FPolitics%2Fgty_chief_justice_john_roberts_jt_111231_wblog.jpg&cfs=1&sx=108&sy=0&sw=269&sh=269,2012-01-01T00:30:26',
# ...

# %%
fi=open('f12345678.txt','w')
for eles in abc2:
    fi.write(eles+'\n')

fi.close()

# %%
! hdfs dfs -put f12345678.txt
# Out:
# put: `f12345678.txt': File exists

# %%
abc3 = sc.textFile('f12345678.txt').cache()

# %%
abc4 = abc3.flatMap(lambda x: x.split(' '))

# %%
abc5 = abc4.map(lambda x: (x,1))

# %%
from operator import add
abcd6 = abc5.reduceByKey(add)

# %%
abc7 = abcd6.map(lambda x: (x[1],x[0]))

# %%
abcd7
# Out:
# PythonRDD[81] at RDD at PythonRDD.scala:52

# %%
abc7.take(2)
# Out:
# [(1, '"\ufeff""86680728811_272953252761568""",86680728811,Chief'),
#  (16, 'Justice')]

# %%
abcd8  = abc7.sortByKey(ascending=False)

# %%
abcd9=abcd8.collect()

# %%
abcd9
# Out:
# [(7865, 'the'),
#  (4988, 'to'),
#  (4566, 'of'),
#  (4552, 'a'),
#  (4205, 'in'),
#  (3149, 'and'),
#  (2409, ''),
#  (2060, 'for'),
#  (2026, 'on'),
#  (1419, 'is'),
#  (1248, 'that'),
#  (1236, 'with'),
#  (1229, 'at'),
#  (1174, 'was'),
#  (1072, 'his'),
#  (991, 'from'),
#  (967, 'you'),
#  (867, 'has'),
#  (800, 'as'),
#  (763, 'an'),
#  (741, 'are'),
#  (737, 'by'),
#  (714, 'her'),
#  (655, 'have'),
#  (642, 'be'),
#  (626, 'this'),
#  (614, 'he'),
#  (570, 'after'),
#  (550, 'who'),
#  (537, 'it'),
#  (511, 'News'),
#  (500, 'will'),
#  (490, 'Obama'),
#  (468, 'Romney'),
#  (429, 'ABC'),
#  (423, 'been'),
#  (415, 'their'),
#  (414, 'not'),
#  (412, 'said'),
#  (402, 'The'),
#  (391, 'about'),
#  (383, 'New'),
#  (372, 'your'),
#  (367, 'but'),
#  (351, 'new'),
#  (348, 'were'),
#  (338, 'more'),
#  (337, 'out'),
#  (329, 'or'),
#  (313, 'she'),
#  (300, 'President'),
#  (296, 'than'),
#  (296, 'they'),
#  (295, 'had'),
#  (294, 'one'),
#  (282, 'U.S.'),
#  (280, 'into'),
# ...

# %%
urlk=[]
for indi in range(200):
    roc = abcd9[indi][1]
    urlk.append(roc+" ")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-4-583c7f305409> in <module>
#       1 urlk=[]
#       2 for indi in range(200):
# ----> 3     roc = abcd9[indi][1]
#       4     urlk.append(roc+" ")
#       5
#
# NameError: name 'abcd9' is not defined

# %%
goht  = listToString(urlk)+" "
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-7b5f2f7bb4da> in <module>
# ----> 1 goht  = listToString(urlk)+" "
#
# NameError: name 'listToString' is not defined

# %%
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-226-1037d4fbad47> in <module>
# ----> 1 tokeining =nltk.word_tokenize(goht)
#
# NameError: name 'nltk' is not defined

# %%
pip install nltk
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
nltk.download()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-6e230a00a763> in <module>
# ----> 1 nltk.download()
#
# NameError: name 'nltk' is not defined

# %%
import nltk

# %%
nltk.download()
# Out:
# NLTK Downloader
# ---------------------------------------------------------------------------
#     d) Download   l) List    u) Update   c) Config   h) Help   q) Quit
# ---------------------------------------------------------------------------
# Downloader> d
#
# Download which package (l=list; x=cancel)?
#   Identifier> punt
#     Error loading punt: Package 'punt' not found in index
# ---------------------------------------------------------------------------
#     d) Download   l) List    u) Update   c) Config   h) Help   q) Quit
# ---------------------------------------------------------------------------
# Downloader> averaged_perceptron_tagger
# Command 'averaged_perceptron_tagger' unrecognized
#
# ---------------------------------------------------------------------------
#     d) Download   l) List    u) Update   c) Config   h) Help   q) Quit
# ---------------------------------------------------------------------------
# Downloader> d
#
# ...

# %%
tokeining =nltk.word_tokenize(goht)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-7-1037d4fbad47> in <module>
# ----> 1 tokeining =nltk.word_tokenize(goht)
#
# NameError: name 'goht' is not defined

# %%
chulk = nltk.pos_tag(tokeining)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-5-8970b8e82f34> in <module>
# ----> 1 chulk = nltk.pos_tag(tokeining)
#
# NameError: name 'tokeining' is not defined

# %%
last=[]
for jo in range(len(chulk)):
    if(chulk[jo][1][0]=='N'):
        last.append(chulk[jo])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-6-44889c4b3e8f> in <module>
#       1 last=[]
# ----> 2 for jo in range(len(chulk)):
#       3     if(chulk[jo][1][0]=='N'):
#       4         last.append(chulk[jo])
#
# NameError: name 'chulk' is not defined

# %%
last[0]
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-8-1cdfff2223d9> in <module>
# ----> 1 last[0]
#
# IndexError: list index out of range
